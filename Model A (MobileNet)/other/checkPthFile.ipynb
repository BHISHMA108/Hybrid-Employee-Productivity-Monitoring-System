# %%
import os
print(os.path.getsize("mobilenet_model.pth") / (1024*1024), "MB")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 print(os.path.getsize("mobilenet_model.pth") / (1024*1024), "MB")
#
# File <frozen genericpath>:50, in getsize(filename)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'mobilenet_model.pth'

# %%
import os

print("Current working directory:")
print(os.getcwd())

print("\nFiles/Folders here:")
print(os.listdir())
# Out:
# Current working directory:
# d:\Final Year\Sem 2\Major Project\Model Project\Model A (MobileNet)
#
# Files/Folders here:
# ['checkPthFile.ipynb', 'mid-sem-project-kaggle_8_March.ipynb', 'mobilenet_model.pth', 'mobilenet_model.pth.zip']

# %%
import os

root_path = os.getcwd()  # or give your download folder path

for root, dirs, files in os.walk(root_path):
    for file in files:
        if file.endswith(".pth"):
            full_path = os.path.join(root, file)
            print("FOUND PTH FILE:", full_path)

# %%
import os

path = "mobilenet_model.pth"

if os.path.exists(path):
    if os.path.isfile(path):
        print("✅ It is a FILE")
    elif os.path.isdir(path):
        print("⚠️ It is actually a FOLDER (WhatsApp compression case)")
        print("Contents:", os.listdir(path))
else:
    print("❌ Path does not exist")
# Out:
# ⚠️ It is actually a FOLDER (WhatsApp compression case)
# Contents: ['mobilenet_model']
